# %% [markdown]
# # CTC Detection — Geneformer Fine-tuning
# Fine-tunes Geneformer for circulating tumor cell (CTC) detection in scRNA-seq data.
# Targets EpCAM-low CTCs missed by CellSearch.
#
# **Runtime:** GPU (T4 or better). Runtime > Change runtime type > T4 GPU

# %% [markdown]
# ## 1. Check GPU

# %%
# !git clone https://github.com/gabufle/ctc-detect.git
# %cd ctc-detect
# !pip install transformers==4.41.0 peft==0.11.0 accelerate datasets scanpy anndata pyensembl mygene -q
# !pyensembl install --release 109 --species homo_sapiens

# %%
from google.colab import drive
drive.mount('/content/drive')

# copy h5ad from drive to working directory
# !cp /content/drive/MyDrive/ctc_merged_processed.h5ad data/processed/

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
print('Device:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')
print('VRAM:', round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), 'GB')

# %% [markdown]
# ## 2. Install dependencies

# %%
#%%capture
# !pip install scanpy anndata peft accelerate datasets scikit-learn umap-learn matplotlib seaborn
# !git clone https://huggingface.co/ctheodoris/Geneformer
# !pip install --no-deps ./Geneformer
# !pip install loompy tdigest -q
# !pip install mygene -q
# Out:
# Requirement already satisfied: scanpy in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (1.12.1)
# Requirement already satisfied: anndata in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (0.12.16)
# Requirement already satisfied: peft in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (0.19.1)
# Requirement already satisfied: accelerate in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (1.13.0)
# Collecting datasets
#   Downloading datasets-5.0.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scikit-learn in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (1.9.0)
# Requirement already satisfied: umap-learn in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (0.5.12)
# Requirement already satisfied: matplotlib in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (3.10.9)
# Requirement already satisfied: seaborn in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: certifi in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (2026.5.20)
# Requirement already satisfied: fast-array-utils>=1.4 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from fast-array-utils[accel,sparse]>=1.4->scanpy) (1.4.1)
# Requirement already satisfied: h5py>=3.11 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (3.16.0)
# Requirement already satisfied: joblib in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (1.5.3)
# Requirement already satisfied: legacy-api-wrap>=1.5 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (1.5)
# Requirement already satisfied: natsort in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.8.8 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (3.6.1)
# Requirement already satisfied: numba>=0.60 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (0.65.1)
# Requirement already satisfied: numpy>=2 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (2.4.6)
# Requirement already satisfied: packaging>=25 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (26.2)
# Requirement already satisfied: pandas>=2.3 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (2.3.3)
# Requirement already satisfied: patsy in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (0.6.0)
# Requirement already satisfied: scipy>=1.13 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (1.17.1)
# Requirement already satisfied: session-info2 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (0.4.1)
# Requirement already satisfied: statsmodels>=0.14.5 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (0.14.6)
# Requirement already satisfied: tqdm in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scanpy) (4.68.1)
# Requirement already satisfied: array-api-compat>=1.7.1 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from anndata) (1.14.0)
# Requirement already satisfied: scverse-misc>=0.0.3 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from anndata) (0.0.7)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from anndata) (3.2.1)
# Requirement already satisfied: psutil in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from peft) (7.2.2)
# Requirement already satisfied: pyyaml in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from peft) (6.0.3)
# Requirement already satisfied: torch>=1.13.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from peft) (2.12.0)
# Requirement already satisfied: transformers in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from peft) (5.10.2)
# Requirement already satisfied: safetensors in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from peft) (0.7.0)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from peft) (1.18.0)
# Requirement already satisfied: filelock in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from datasets) (3.29.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from datasets) (24.0.0)
# Collecting dill<0.4.2,>=0.3.0 (from datasets)
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.32.2 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from datasets) (2.34.2)
# Requirement already satisfied: httpx<1.0.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from datasets) (0.28.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.8.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting multiprocess<0.70.20 (from datasets)
#   Downloading multiprocess-0.70.19-py313-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: fsspec<=2026.4.0,>=2023.1.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2026.4.0)
# Requirement already satisfied: narwhals>=2.0.1 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pillow>=8 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.14.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.3 kB)
# Requirement already satisfied: anyio in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from huggingface_hub>=0.25.0->peft) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from huggingface_hub>=0.25.0->peft) (1.5.0)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from huggingface_hub>=0.25.0->peft) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from huggingface_hub>=0.25.0->peft) (4.15.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from numba>=0.60->scanpy) (0.47.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from pandas>=2.3->scanpy) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from pandas>=2.3->scanpy) (2026.2)
# Requirement already satisfied: six>=1.5 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (2.7.0)
# Requirement already satisfied: setuptools<82 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from torch>=1.13.0->peft) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: donfig>=0.8 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from zarr!=3.0.*,>=2.18.7->anndata) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from zarr!=3.0.*,>=2.18.7->anndata) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from zarr!=3.0.*,>=2.18.7->anndata) (0.16.5)
# Requirement already satisfied: regex>=2025.10.22 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from transformers->peft) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from transformers->peft) (0.22.2)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets)
#   Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.8.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets)
#   Downloading multidict-6.7.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets)
#   Downloading propcache-0.5.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets)
#   Downloading yarl-1.24.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (94 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.25.0->peft) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.25.0->peft) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.25.0->peft) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.25.0->peft) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.25.0->peft) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/deegs/ctc-detect/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.25.0->peft) (0.1.2)
# Downloading datasets-5.0.0-py3-none-any.whl (555 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 4.6 MB/s eta 0:00:00
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
# Downloading multiprocess-0.70.19-py313-none-any.whl (156 kB)
# Downloading xxhash-3.8.1-cp313-cp313-macosx_11_0_arm64.whl (32 kB)
# Downloading aiohttp-3.14.1-cp313-cp313-macosx_11_0_arm64.whl (508 kB)
# Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-macosx_11_0_arm64.whl (49 kB)
# Downloading multidict-6.7.1-cp313-cp313-macosx_11_0_arm64.whl (43 kB)
# Downloading propcache-0.5.2-cp313-cp313-macosx_11_0_arm64.whl (54 kB)
# Downloading yarl-1.24.2-cp313-cp313-macosx_11_0_arm64.whl (91 kB)
# Installing collected packages: xxhash, propcache, multidict, frozenlist, dill, attrs, aiohappyeyeballs, yarl, multiprocess, aiosignal, aiohttp, datasets
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.1 aiosignal-1.4.0 attrs-26.1.0 datasets-5.0.0 dill-0.4.1 frozenlist-1.8.0 multidict-6.7.1 multiprocess-0.70.19 propcache-0.5.2 xxhash-3.8.1 yarl-1.24.2
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Cloning into 'Geneformer'...
# remote: Enumerating objects: 1255, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 1255 (delta 1), reused 0 (delta 0), pack-reused 1247 (from 1)
# Receiving objects: 100% (1255/1255), 4.80 MiB | 13.69 MiB/s, done.
# Resolving deltas: 100% (810/810), done.
# Filtering content: 100% (24/24), 3.32 GiB | 72.21 MiB/s, done.
# Processing ./Geneformer
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: geneformer
#   Building wheel for geneformer (pyproject.toml) ... done
#   Created wheel for geneformer: filename=geneformer-0.1.0-py3-none-any.whl size=2980810 sha256=54ff96594316ee28e46674718a3ae5130307b27f4cfd102aaa3c069a98f21776
#   Stored in directory: /private/var/folders/8q/03ywpvb57ld2d43pcc7s0z8r0000gn/T/pip-ephem-wheel-cache-7gk8u2_q/wheels/0f/38/4e/c43c2392dda0f73ab3d31befd8dfc525a078586dc3ae3fcb79
# Successfully built geneformer
# Installing collected packages: geneformer
# Successfully installed geneformer-0.1.0
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# geneformer 0.1.0 requires bitsandbytes, which is not installed.
# geneformer 0.1.0 requires optuna, which is not installed.
# geneformer 0.1.0 requires optuna-integration, which is not installed.
# geneformer 0.1.0 requires ray, which is not installed.
# geneformer 0.1.0 requires tensorboard, which is not installed.
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 3. Mount Google Drive and load data

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.makedirs('data/processed', exist_ok=True)
os.makedirs('results/checkpoints/best_model', exist_ok=True)
os.makedirs('results/figures', exist_ok=True)

# Copy h5ad from Drive
# !cp /content/drive/MyDrive/ctc_merged_processed.h5ad data/processed/
print('h5ad loaded')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#       3
#       4 import os
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# ## 4. Load and inspect data

# %%
import scanpy as sc
import numpy as np
import pandas as pd

#adata = sc.read_h5ad('/content/drive/MyDrive/CTC - testing/ctc_merged_processed.h5ad')
adata = sc.read_h5ad('/Users/deegs/Desktop/ctc-detect/data/external/gse109761/data.h5ad')
print('Cells:', adata.n_obs)
print('Genes:', adata.n_vars)
print('Columns:', adata.obs.columns.tolist())
print()
print('CTC breakdown:')
print(adata.obs['is_ctc'].value_counts())
print()
print('EpCAM status breakdown:')
print(adata.obs['epcam_status'].value_counts())
# Out:
# Cells: 45
# Genes: 19955
# Columns: []
#
# CTC breakdown:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/ctc-detect/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7096 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'is_ctc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 12
#       8 print('Genes:', adata.n_vars)
#       9 print('Columns:', adata.obs.columns.tolist())
#      10 print()
#      11 print('CTC breakdown:')
# ---> 12 print(adata.obs['is_ctc'].value_counts())
#      13 print()
#      14 print('EpCAM status breakdown:')
#      15 print(adata.obs['epcam_status'].value_counts())
#
# File ~/ctc-detect/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4109
#    4110         if is_single_key:
#    4111             if self.columns.nlevels > 1:
#    4112                 return self._getitem_multilevel(key)
# -> 4113             indexer = self.columns.get_loc(key)
#    4114             if is_integer(indexer):
#    4115                 indexer = [indexer]
#    4116         else:
#
# File ~/ctc-detect/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'is_ctc'

# %% [markdown]
# ## 5. Tokenize for Geneformer

# %%
# Geneformer needs Ensembl IDs - convert gene symbols
# First check what format our genes are in
print('First 10 gene names:', adata.var_names[:10].tolist())
print('Gene name format looks like Ensembl?', adata.var_names[0].startswith('ENSG'))

# %%
from pyensembl import EnsemblRelease
genome = EnsemblRelease(109)

def symbol_to_ensembl(symbol):
    try:
        genes = genome.genes_by_name(symbol)
        if genes:
            return genes[0].gene_id
        return None
    except:
        return None

print('Converting gene symbols to Ensembl IDs...')
adata.var['ensembl_id'] = [symbol_to_ensembl(g) for g in adata.var_names]

# Report conversion rate
n_converted = adata.var['ensembl_id'].notna().sum()
print(f'Converted: {n_converted}/{adata.n_vars} genes ({100*n_converted/adata.n_vars:.1f}%)')

# Filter to converted genes only
adata = adata[:, adata.var['ensembl_id'].notna()].copy()
adata.var_names = adata.var['ensembl_id'].values
print(f'Genes after filtering: {adata.n_vars}')
print('First 5 Ensembl IDs:', adata.var_names[:5].tolist())

# %%
import os
for root, dirs, files in os.walk('./Geneformer'):
    for f in files:
        print(os.path.join(root, f))

# %%
import pickle
import numpy as np
from scipy.sparse import issparse

# Load Geneformer V2 vocabulary files
with open('./Geneformer/geneformer/gene_median_dictionary_gc104M.pkl', 'rb') as f:
    gene_median_dict = pickle.load(f)

with open('./Geneformer/geneformer/token_dictionary_gc104M.pkl', 'rb') as f:
    token_dict = pickle.load(f)

print(f'Vocab size: {len(token_dict)} tokens')
print(f'Genes in median dict: {len(gene_median_dict)}')

def tokenize_cell(expression_vector, gene_names):
    if issparse(expression_vector):
        expression_vector = expression_vector.toarray().flatten()
    else:
        expression_vector = np.array(expression_vector).flatten()

    expressed_mask = expression_vector > 0
    expressed_genes = gene_names[expressed_mask]
    expressed_values = expression_vector[expressed_mask]

    normalized = []
    for gene, val in zip(expressed_genes, expressed_values):
        median = gene_median_dict.get(gene, None)
        if median and median > 0:
            normalized.append((gene, val / median))

    normalized.sort(key=lambda x: x[1], reverse=True)
    token_ids = [token_dict[g] for g, _ in normalized if g in token_dict]
    return token_ids

print('Tokenizing cells...')
gene_names = np.array(adata.var_names)
all_input_ids = []
all_lengths = []

for i in range(adata.n_obs):
    if i % 1000 == 0:
        print(f'  {i}/{adata.n_obs}')
    expr = adata.X[i]
    token_ids = tokenize_cell(expr, gene_names)
    all_input_ids.append(token_ids)
    all_lengths.append(len(token_ids))

print(f'Done. Mean length: {np.mean(all_lengths):.0f} | Max: {max(all_lengths)} | Min: {min(all_lengths)}')

# %% [markdown]
# ## 6. Split, pad and prepare datasets

# %%
from datasets import Dataset
import pandas as pd

# Build dataset from tokenized cells
dataset_dict = {
    'input_ids': all_input_ids,
    'length': all_lengths,
    'label': [int(x) for x in adata.obs['is_ctc'].values],
    'is_ctc': [int(x) for x in adata.obs['is_ctc'].values],
    'epcam_status': [str(x) for x in adata.obs['epcam_status'].values],
}

full_ds = Dataset.from_dict(dataset_dict)
print(full_ds)
print(f'CTCs: {sum(full_ds["label"])} | Normal: {len(full_ds) - sum(full_ds["label"])}')

# %%
from datasets import DatasetDict

# Stratified split
ctc_idx    = [i for i, x in enumerate(full_ds['label']) if x == 1]
normal_idx = [i for i, x in enumerate(full_ds['label']) if x == 0]
np.random.seed(42)
np.random.shuffle(ctc_idx)
np.random.shuffle(normal_idx)

def split_indices(idx, train=0.7, val=0.15):
    n = len(idx)
    return idx[:int(n*train)], idx[int(n*train):int(n*(train+val))], idx[int(n*(train+val)):]

ctc_tr, ctc_va, ctc_te       = split_indices(ctc_idx)
norm_tr, norm_va, norm_te    = split_indices(normal_idx)

train_idx = sorted(ctc_tr + norm_tr)
val_idx   = sorted(ctc_va + norm_va)
test_idx  = sorted(ctc_te + norm_te)

train_ds = full_ds.select(train_idx)
val_ds   = full_ds.select(val_idx)
test_ds  = full_ds.select(test_idx)

print(f'Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}')
print(f'Train CTCs: {sum(train_ds["label"])} | Normal: {len(train_ds) - sum(train_ds["label"])}')

# %%
# Pad and truncate to 2048 (Geneformer pretraining max)
MAX_LENGTH = 2048

def pad_and_truncate(example):
    ids = example['input_ids'][:MAX_LENGTH]
    length = len(ids)
    example['input_ids'] = ids + [0] * (MAX_LENGTH - length)
    example['attention_mask'] = [1] * length + [0] * (MAX_LENGTH - length)
    example['length'] = length
    return example

train_ds = train_ds.map(pad_and_truncate, num_proc=2)
val_ds   = val_ds.map(pad_and_truncate, num_proc=2)
test_ds  = test_ds.map(pad_and_truncate, num_proc=2)

# Set torch format
cols = ['input_ids', 'attention_mask', 'label']
train_ds.set_format(type='torch', columns=cols)
val_ds.set_format(type='torch', columns=cols)
test_ds.set_format(type='torch', columns=cols)

print('Sequence length check:', len(train_ds[0]['input_ids']))
print('Ready for training')

# %% [markdown]
# ## 7. Load model and apply LoRA

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
print(os.path.exists('/content/drive/MyDrive/ctc_tokenized_train'))
print(os.path.exists('/content/drive/MyDrive/ctc_tokenized_val'))
print(os.path.exists('/content/drive/MyDrive/ctc_tokenized_test'))

# %%
import torch
import torch.nn as nn
from transformers import AutoModelForSequenceClassification
from peft import LoraConfig, get_peft_model, TaskType

MODEL_NAME = './Geneformer/Geneformer-V1-10M'

model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=2,
    ignore_mismatched_sizes=True,
)
model.gradient_checkpointing_enable()

lora_config = LoraConfig(
    task_type=TaskType.SEQ_CLS,
    r=8,
    lora_alpha=16,
    lora_dropout=0.1,
    target_modules=['query', 'value'],
    modules_to_save=['classifier', 'pooler'],
    bias='none',
)
model = get_peft_model(model, lora_config)
model.print_trainable_parameters()

# %%
# !mkdir -p /content/drive/MyDrive/ctc_detect_data
full_ds.save_to_disk('/content/drive/MyDrive/ctc_detect_data/full')
train_ds.save_to_disk('/content/drive/MyDrive/ctc_detect_data/train')
val_ds.save_to_disk('/content/drive/MyDrive/ctc_detect_data/val')
test_ds.save_to_disk('/content/drive/MyDrive/ctc_detect_data/test')
print('backed up to drive')

# %% [markdown]
# ## 8. Train

# %%
from transformers import TrainingArguments, Trainer, EarlyStoppingCallback, default_data_collator
from sklearn.metrics import roc_auc_score, average_precision_score, confusion_matrix

# Class weights
labels_arr = np.array(train_ds['label'])
n_normal = (labels_arr == 0).sum()
n_ctc    = (labels_arr == 1).sum()
w = torch.tensor([1.0/n_normal, 1.0/n_ctc], dtype=torch.float32)
w = w / w.sum()
print(f'Class weights — Normal: {w[0]:.4f} | CTC: {w[1]:.4f}')
print(f'Class balance — Normal: {n_normal} | CTC: {n_ctc}')

class WeightedTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs.pop('labels')
        outputs = model(**inputs)
        loss = nn.CrossEntropyLoss(weight=w.to(outputs.logits.device))(outputs.logits, labels)
        return (loss, outputs) if return_outputs else loss

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    probs = torch.softmax(torch.tensor(logits), dim=-1).numpy()[:, 1]
    preds = (probs >= 0.5).astype(int)
    if len(np.unique(labels)) < 2:
        return {'auroc': 0.0, 'auprc': 0.0, 'sensitivity': 0.0, 'specificity': 0.0}
    tn, fp, fn, tp = confusion_matrix(labels, preds, labels=[0,1]).ravel()
    return {
        'auroc':       roc_auc_score(labels, probs),
        'auprc':       average_precision_score(labels, probs),
        'sensitivity': tp / max(tp+fn, 1),
        'specificity': tn / max(tn+fp, 1),
    }

training_args = TrainingArguments(
    output_dir='results/checkpoints/best_model',
    num_train_epochs=20,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    learning_rate=1e-4,
    warmup_steps=100,
    weight_decay=0.01,
    eval_strategy='epoch',
    save_strategy='epoch',
    load_best_model_at_end=True,
    metric_for_best_model='auprc',
    greater_is_better=True,
    logging_steps=10,
    fp16=True,
    dataloader_num_workers=2,
    dataloader_pin_memory=True,
    report_to='none',
    max_grad_norm=1.0,
)

trainer = WeightedTrainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    compute_metrics=compute_metrics,
    data_collator=default_data_collator,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

print('Starting training...')
train_result = trainer.train()
print('Training complete')

# %% [markdown]
# ## 9. Evaluate on test set

# %%
from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay
import matplotlib.pyplot as plt

test_result  = trainer.predict(test_ds)
probs        = torch.softmax(torch.tensor(test_result.predictions), dim=-1).numpy()[:, 1]
labels       = test_result.label_ids
preds        = (probs >= 0.5).astype(int)

tn, fp, fn, tp = confusion_matrix(labels, preds, labels=[0,1]).ravel()
auroc       = roc_auc_score(labels, probs)
auprc       = average_precision_score(labels, probs)
sensitivity = tp / max(tp+fn, 1)
specificity = tn / max(tn+fp, 1)

print('=== TEST SET RESULTS ===')
print(f'AUROC:       {auroc:.4f}')
print(f'AUPRC:       {auprc:.4f}')
print(f'Sensitivity: {sensitivity:.4f}')
print(f'Specificity: {specificity:.4f}')

if sensitivity < 0.7:
    print('WARNING: Sensitivity below 0.7 — model missing too many CTCs')

# ROC and PR curves
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
RocCurveDisplay.from_predictions(labels, probs, ax=axes[0], name='Geneformer-CTC')
PrecisionRecallDisplay.from_predictions(labels, probs, ax=axes[1], name='Geneformer-CTC')
axes[0].set_title('ROC Curve')
axes[1].set_title('Precision-Recall Curve')
plt.tight_layout()
plt.savefig('results/figures/roc_pr_curves.png', dpi=150)
plt.show()
print('Saved to results/figures/roc_pr_curves.png')

# %% [markdown]
# ## 10. EpCAM subgroup analysis

# %%
# Get epcam status for test cells
test_epcam = [str(full_ds[i]['epcam_status']) for i in test_idx]

results_df = pd.DataFrame({
    'label':        labels,
    'prob':         probs,
    'pred':         preds,
    'epcam_status': test_epcam,
})

print('=== EPCAM SUBGROUP ANALYSIS ===')
for status in results_df['epcam_status'].unique():
    subset = results_df[results_df['epcam_status'] == status]
    ctc_subset = subset[subset['label'] == 1]
    if len(ctc_subset) == 0:
        continue
    detected = (ctc_subset['pred'] == 1).sum()
    sensitivity_sub = detected / len(ctc_subset)
    print(f'\nEpCAM status: {status}')
    print(f'  CTC cells:   {len(ctc_subset)}')
    print(f'  Detected:    {detected}')
    print(f'  Sensitivity: {sensitivity_sub:.4f}')

# %% [markdown]
# ## 11. UMAP visualization

# %%
import scanpy as sc
import seaborn as sns

# Build anndata from test set for UMAP
test_input_ids = np.array(test_ds['input_ids'])

adata_test = sc.AnnData(
    X=test_input_ids.astype(np.float32),
)
adata_test.obs['true_label']   = ['CTC' if l == 1 else 'Normal' for l in labels]
adata_test.obs['ctc_prob']     = probs
adata_test.obs['predicted']    = ['CTC' if p == 1 else 'Normal' for p in preds]
adata_test.obs['uncertain']    = ((probs >= 0.4) & (probs <= 0.6)).astype(str)
adata_test.obs['epcam_status'] = test_epcam

sc.pp.pca(adata_test, n_comps=50)
sc.pp.neighbors(adata_test)
sc.tl.umap(adata_test)

fig, axes = plt.subplots(2, 2, figsize=(14, 12))
sc.pl.umap(adata_test, color='true_label',   ax=axes[0,0], show=False, title='Ground Truth')
sc.pl.umap(adata_test, color='ctc_prob',     ax=axes[0,1], show=False, title='CTC Probability', cmap='Reds')
sc.pl.umap(adata_test, color='predicted',    ax=axes[1,0], show=False, title='Predicted Label')
sc.pl.umap(adata_test, color='epcam_status', ax=axes[1,1], show=False, title='EpCAM Status')
plt.tight_layout()
plt.savefig('results/figures/umap_predictions.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved to results/figures/umap_predictions.png')

# %% [markdown]
# ## 12. Save checkpoint to Google Drive

# %%
import shutil

trainer.save_model('results/checkpoints/best_model')

# Copy checkpoint and results to Drive
# !cp -r results/checkpoints/best_model /content/drive/MyDrive/ctc_detect_checkpoint
# !cp -r results/figures /content/drive/MyDrive/ctc_detect_figures

print('Checkpoint saved to Google Drive: ctc_detect_checkpoint/')
print('Figures saved to Google Drive: ctc_detect_figures/')
print('Done!')

# %%
trainer.save_model('results/checkpoints/best_model')
# !cp -r results/checkpoints/best_model /content/drive/MyDrive/ctc_detect_checkpoint
# !cp -r results/figures /content/drive/MyDrive/ctc_detect_figures
print('saved')

# %%
# download figures and results locally first
from google.colab import files

# zip results folder
# !zip -r results.zip results/figures/ results/metrics.json
files.download('results.zip')
